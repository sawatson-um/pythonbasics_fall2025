# %% [markdown]
# # Python basics week 7 - APIs

# %%
# install whichever packages you don't have yet
pip install crossref-commons pandas
# Out:
# Collecting crossref-commons
#   Downloading crossref_commons-0.0.7-py3-none-any.whl.metadata (3.2 kB)
# Collecting ratelimit>=2.2.1 (from crossref-commons)
#   Downloading ratelimit-2.2.1.tar.gz (5.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests>=2.18.4 in c:\users\swatson\appdata\local\programs\python\python313\lib\site-packages (from crossref-commons) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\swatson\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.18.4->crossref-commons) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\swatson\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.18.4->crossref-commons) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\swatson\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.18.4->crossref-commons) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\swatson\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.18.4->crossref-commons) (2025.7.14)
# Downloading crossref_commons-0.0.7-py3-none-any.whl (14 kB)
# Building wheels for collected packages: ratelimit
#   Building wheel for ratelimit (pyproject.toml): started
#   Building wheel for ratelimit (pyproject.toml): finished with status 'done'
#   Created wheel for ratelimit: filename=ratelimit-2.2.1-py3-none-any.whl size=6007 sha256=8be7ca6b18be12d68b4b1130375f76bcd676fe13608347173b7661e16a3b11a1
#   Stored in directory: c:\users\swatson\appdata\local\pip\cache\wheels\bc\be\ca\8b600816432fb04a8cc69b18ae7bb057a24870e0f9dd14ad1c
# Successfully built ratelimit
# Installing collected packages: ratelimit, crossref-commons
#
#    -------------------- ------------------- 1/2 [crossref-commons]
#    ---------------------------------------- 2/2 [crossref-commons]
#
# Successfully installed crossref-commons-0.0.7 ratelimit-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import crossref_commons.retrieval
import pandas as pd

# %%
study = crossref_commons.retrieval.get_publication_as_json('10.5621/sciefictstud.40.2.0382')
study
# Out:
# {'indexed': {'date-parts': [[2025, 8, 2]],
#   'date-time': '2025-08-02T18:35:31Z',
#   'timestamp': 1754159731358,
#   'version': '3.41.2'},
#  'reference-count': 0,
#  'publisher': 'University of California Press',
#  'issue': '2',
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'short-container-title': ['Science Fiction Studies'],
#  'published-print': {'date-parts': [[2013]]},
#  'DOI': '10.5621/sciefictstud.40.2.0382',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2013, 7, 2]],
#   'date-time': '2013-07-02T08:51:49Z',
#   'timestamp': 1372755109000},
#  'page': '382',
#  'source': 'Crossref',
#  'is-referenced-by-count': 0,
#  'title': ['Humanism on Gallifrey'],
#  'prefix': '10.1525',
#  'volume': '40',
#  'author': [{'family': 'Elizabeth Lundberg',
#    'sequence': 'first',
#    'affiliation': []}],
#  'member': '408',
#  'container-title': ['Science Fiction Studies'],
#  'original-title': [],
#  'deposited': {'date-parts': [[2025, 7, 25]],
#   'date-time': '2025-07-25T20:47:51Z',
#   'timestamp': 1753476471000},
#  'score': 1,
#  'resource': {'primary': {'URL': 'https://online.ucpress.edu/sfs/article/40/Part%202%20(120)/382/205840'}},
#  'subtitle': [],
#  'short-title': [],
#  'issued': {'date-parts': [[2013]]},
#  'references-count': 0,
#  'journal-issue': {'issue': '2', 'published-print': {'date-parts': [[2013]]}},
#  'alternative-id': ['10.5621/sciefictstud.40.2.0382'],
#  'URL': 'https://doi.org/10.5621/sciefictstud.40.2.0382',
#  'relation': {},
#  'ISSN': ['0091-7729'],
#  'issn-type': [{'type': 'print', 'value': '0091-7729'}],
#  'subject': [],
#  'published': {'date-parts': [[2013]]}}

# %%
study
# This looks an awful lot like a dictionary
# Out:
# {'indexed': {'date-parts': [[2025, 8, 2]],
#   'date-time': '2025-08-02T18:35:31Z',
#   'timestamp': 1754159731358,
#   'version': '3.41.2'},
#  'reference-count': 0,
#  'publisher': 'University of California Press',
#  'issue': '2',
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'short-container-title': ['Science Fiction Studies'],
#  'published-print': {'date-parts': [[2013]]},
#  'DOI': '10.5621/sciefictstud.40.2.0382',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2013, 7, 2]],
#   'date-time': '2013-07-02T08:51:49Z',
#   'timestamp': 1372755109000},
#  'page': '382',
#  'source': 'Crossref',
#  'is-referenced-by-count': 0,
#  'title': ['Humanism on Gallifrey'],
#  'prefix': '10.1525',
#  'volume': '40',
#  'author': [{'family': 'Elizabeth Lundberg',
#    'sequence': 'first',
#    'affiliation': []}],
#  'member': '408',
#  'container-title': ['Science Fiction Studies'],
#  'original-title': [],
#  'deposited': {'date-parts': [[2025, 7, 25]],
#   'date-time': '2025-07-25T20:47:51Z',
#   'timestamp': 1753476471000},
#  'score': 1,
#  'resource': {'primary': {'URL': 'https://online.ucpress.edu/sfs/article/40/Part%202%20(120)/382/205840'}},
#  'subtitle': [],
#  'short-title': [],
#  'issued': {'date-parts': [[2013]]},
#  'references-count': 0,
#  'journal-issue': {'issue': '2', 'published-print': {'date-parts': [[2013]]}},
#  'alternative-id': ['10.5621/sciefictstud.40.2.0382'],
#  'URL': 'https://doi.org/10.5621/sciefictstud.40.2.0382',
#  'relation': {},
#  'ISSN': ['0091-7729'],
#  'issn-type': [{'type': 'print', 'value': '0091-7729'}],
#  'subject': [],
#  'published': {'date-parts': [[2013]]}}

# %%
study['publisher']  # you can call keys directly on the JSON object
# Out:
# 'University of California Press'

# %%
# normally, we could do something like this, but it won't work with this json structure
df = pd.DataFrame(study)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # normally, we could do something like this, but it won't work with this json structure
# ----> 2 df = pd.DataFrame(study)
#
# File c:\Users\swatson\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\swatson\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\swatson\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\swatson\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
# Instead, we use json_normalize to flatten the JSON structure
df = pd.json_normalize(study)
df
# Out:
#    reference-count                       publisher issue  \
# 0                0  University of California Press     2
#
#        short-container-title                             DOI             type  \
# 0  [Science Fiction Studies]  10.5621/sciefictstud.40.2.0382  journal-article
#
#   page    source  is-referenced-by-count                    title  ...  \
# 0  382  Crossref                       0  [Humanism on Gallifrey]  ...
#
#       created.date-time created.timestamp deposited.date-parts  \
# 0  2013-07-02T08:51:49Z     1372755109000      [[2025, 7, 25]]
#
#     deposited.date-time deposited.timestamp  \
# 0  2025-07-25T20:47:51Z       1753476471000
#
#                                 resource.primary.URL  issued.date-parts  \
# 0  https://online.ucpress.edu/sfs/article/40/Part...           [[2013]]
#
#   journal-issue.issue journal-issue.published-print.date-parts  \
# 0                   2                                 [[2013]]
#
#    published.date-parts
# 0              [[2013]]
#
# [1 rows x 43 columns]

# %%
df['title'][0]
# Out:
# ['Humanism on Gallifrey']

# %%
type(df['title'][0])
# Out:
# list

# %%
# You might think we could just do this, but it won't work in upcoming versions of pandas
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

df['title'][0] = str(df['title'][0])
# Out:
# C:\Users\swatson\AppData\Local\Temp\ipykernel_191404\3864859956.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['title'][0] = str(df['title'][0])
# C:\Users\swatson\AppData\Local\Temp\ipykernel_191404\3864859956.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['title'][0] = str(df['title'][0])

# %%
# We do this instead
df.loc[0, "title"] = str(df['title'][0]).replace('\'', '')  # Get rid of the single quotes around the title while we're at it
df
# Out:
#    reference-count                       publisher issue  \
# 0                0  University of California Press     2
#
#        short-container-title                             DOI             type  \
# 0  [Science Fiction Studies]  10.5621/sciefictstud.40.2.0382  journal-article
#
#   page    source  is-referenced-by-count                    title  ...  \
# 0  382  Crossref                       0  [Humanism on Gallifrey]  ...
#
#       created.date-time created.timestamp deposited.date-parts  \
# 0  2013-07-02T08:51:49Z     1372755109000      [[2025, 7, 25]]
#
#     deposited.date-time deposited.timestamp  \
# 0  2025-07-25T20:47:51Z       1753476471000
#
#                                 resource.primary.URL  issued.date-parts  \
# 0  https://online.ucpress.edu/sfs/article/40/Part...           [[2013]]
#
#   journal-issue.issue journal-issue.published-print.date-parts  \
# 0                   2                                 [[2013]]
#
#    published.date-parts
# 0              [[2013]]
#
# [1 rows x 43 columns]

# %%
from crossref_commons.iteration import iterate_publications_as_json
DOIS = []
filter = {'member': '3444',}
for pub in iterate_publications_as_json(max_results=100, filter=filter):
  DOIS.append(pub['DOI'])

DOIS
# Out:
# ['10.5962/bhl.title.49941',
#  '10.5962/bhl.title.108915',
#  '10.5962/bhl.title.94153',
#  '10.5962/bhl.part.23369',
#  '10.5479/si.00963801.30-1462.695',
#  '10.5962/bhl.title.33142',
#  '10.5962/p.313802',
#  '10.5962/bhl.title.142240',
#  '10.5962/bhl.title.42454',
#  '10.5962/bhl.title.65831',
#  '10.5479/si.00775630.29.1',
#  '10.5479/si.00963801.1126.457',
#  '10.5962/bhl.title.109197',
#  '10.5962/bhl.title.63910',
#  '10.5479/si.00810282.250',
#  '10.5962/bhl.part.1065',
#  '10.5479/si.00775630.93.1',
#  '10.5962/bhl.title.33014',
#  '10.5962/bhl.title.28774',
#  '10.5962/bhl.title.140653',
#  '10.5962/bhl.title.26910',
#  '10.5962/bhl.part.4855',
#  '10.5962/bhl.title.117805',
#  '10.5962/bhl.title.14483',
#  '10.5962/bhl.title.61362',
#  '10.5962/bhl.title.147308',
#  '10.5962/bhl.title.138321',
#  '10.5962/bhl.title.104186',
#  '10.5962/bhl.title.101143',
#  '10.5962/bhl.title.55910',
#  '10.5962/bhl.title.147959',
#  '10.5962/bhl.title.130362',
#  '10.5962/bhl.title.50454',
#  '10.5962/bhl.title.146247',
#  '10.5962/p.320447',
#  '10.5962/bhl.title.4533',
#  '10.5962/bhl.title.102208',
#  '10.5962/bhl.title.107699',
#  '10.5962/bhl.part.9093',
#  '10.5962/bhl.title.110681',
#  '10.5479/si.16549779',
#  '10.5962/bhl.title.62557',
#  '10.5962/bhl.title.30270',
#  '10.5962/bhl.title.139641',
#  '10.5962/bhl.title.156000',
#  '10.5962/bhl.title.150652',
#  '10.5479/si.00963801.115-3480.61',
#  '10.5962/bhl.title.141022',
#  '10.5962/bhl.title.56194',
#  '10.5962/bhl.title.141399',
#  '10.5962/bhl.title.146486',
#  '10.5962/bhl.title.115665',
#  '10.5962/bhl.title.139482',
#  '10.5962/p.310204',
#  '10.5962/bhl.title.149100',
#  '10.5962/bhl.title.123599',
#  '10.5962/bhl.title.126014',
#  '10.5962/bhl.title.110032',
#  '10.5962/bhl.title.121267',
#  '10.5962/bhl.part.5889',
#  '10.5962/bhl.title.97449',
#  '10.5479/ads/bib/1911pusno.7d.2',
#  '10.5962/p.309905',
#  '10.5962/bhl.part.18172',
#  '10.5962/bhl.title.159044',
#  '10.5962/bhl.title.148321',
#  '10.5479/si.00963801.2685',
#  '10.5962/bhl.title.124319',
#  '10.5962/bhl.title.150518',
#  '10.5962/bhl.title.113343',
#  '10.5962/bhl.part.2566',
#  '10.5962/bhl.title.129723',
#  '10.5962/bhl.title.13699',
#  '10.5962/bhl.title.104410',
#  '10.5962/bhl.title.153106',
#  '10.5962/bhl.title.87137',
#  '10.5962/bhl.title.7999',
#  '10.5962/bhl.title.11801',
#  '10.5962/bhl.title.57591',
#  '10.5962/bhl.title.96305',
#  '10.5962/p.309945',
#  '10.5962/bhl.title.119404',
#  '10.5962/bhl.title.15608',
#  '10.5962/bhl.title.135757',
#  '10.5962/bhl.part.14617',
#  '10.5962/bhl.title.129514',
#  '10.5962/bhl.title.41983',
#  '10.5962/bhl.title.99416',
#  '10.5479/ads/bib/2007ivoa.spec.0402m',
#  '10.5962/bhl.title.124978',
#  '10.5962/bhl.title.131271',
#  '10.5962/bhl.title.134512',
#  '10.5962/bhl.title.96290',
#  '10.5962/p.319258',
#  '10.5962/bhl.title.160246',
#  '10.5962/bhl.title.6118',
#  '10.5962/bhl.title.25933',
#  '10.5962/bhl.title.84489',
#  '10.5962/bhl.title.133707',
#  '10.5962/p.321505']

# %%
df = pd.json_normalize(crossref_commons.retrieval.get_publication_as_json('10.5962/bhl.title.49941'))
df
# Out:
#   publisher-location  reference-count   publisher short-container-title  \
# 0           London :                0  H.G. Bohn,                    []
#
#                        DOI       type    source  is-referenced-by-count  \
# 0  10.5962/bhl.title.49941  monograph  Crossref                       1
#
#                                                title   prefix  ...  \
# 0  [A selection of the birds of Brazil and Mexico...  10.5962  ...
#
#   published-print.date-parts created.date-parts     created.date-time  \
# 0                   [[1841]]   [[2011, 11, 23]]  2011-11-23T21:51:04Z
#
#   created.timestamp  deposited.date-parts   deposited.date-time  \
# 0     1322085064000      [[2011, 11, 23]]  2011-11-23T21:51:19Z
#
#   deposited.timestamp                               resource.primary.URL  \
# 0       1322085079000  http://www.biodiversitylibrary.org/bibliograph...
#
#   issued.date-parts published.date-parts
# 0          [[1841]]             [[1841]]
#
# [1 rows x 35 columns]

# %%
for DOI in DOIS:
  response = crossref_commons.retrieval.get_publication_as_json(DOI)
  df = pd.concat([df, pd.json_normalize(response)], ignore_index=True)

df
# Out:
#            publisher-location  reference-count  \
# 0                    London :                0
# 1                    London :                0
# 2          Washington, D.C. :                0
# 3             Portland, Or. :                0
# 4                         NaN                0
# ..                        ...              ...
# 96                    Torino,                0
# 97                   London :                0
# 98         Upper Darby, Pa. :                0
# 99   Marysville, California :                0
# 100                       NaN                0
#
#                                              publisher short-container-title  \
# 0                                           H.G. Bohn,                    []
# 1                                           H.G. Bohn,                    []
# 2                           U.S. Dept. of Agriculture,                    []
# 3    Pacific Northwest Forest and Range Experiment ...                    []
# 4                              Smithsonian Institution                    []
# ..                                                 ...                   ...
# 96                                   Giuseppe Cassone,                    []
# 97                                   Chapman and Hall,                    []
# 98             Northeastern Forest Experiment Station,                    []
# 99                               Donald Morse Nursery,                    []
# 100                            Smithsonian Institution                    []
#
#                           DOI             type    source  \
# 0     10.5962/bhl.title.49941        monograph  Crossref
# 1     10.5962/bhl.title.49941        monograph  Crossref
# 2    10.5962/bhl.title.108915        monograph  Crossref
# 3     10.5962/bhl.title.94153        monograph  Crossref
# 4      10.5962/bhl.part.23369  journal-article  Crossref
# ..                        ...              ...       ...
# 96     10.5962/bhl.title.6118        monograph  Crossref
# 97    10.5962/bhl.title.25933        monograph  Crossref
# 98    10.5962/bhl.title.84489        monograph  Crossref
# 99   10.5962/bhl.title.133707        monograph  Crossref
# 100          10.5962/p.321505  journal-article  Crossref
#
#      is-referenced-by-count  \
# 0                         1
# 1                         1
# 2                         1
# 3                         2
# 4                         1
# ..                      ...
# 96                        0
# 97                        0
# 98                        0
# 99                        0
# 100                       0
#
#                                                  title   prefix  ...  \
# 0    [A selection of the birds of Brazil and Mexico...  10.5962  ...
# 1    [A selection of the birds of Brazil and Mexico...  10.5962  ...
# 2    [Land reclamation policies in the United State...  10.5962  ...
# 3     [Pruning of ponderosa pine : effect on growth /]  10.5962  ...
# 4          [Zwei neue südamerikanische Microdon-Arten]  10.5962  ...
# ..                                                 ...      ...  ...
# 96   [Flora medico-farmaceutica, compilata dal dott...  10.5962  ...
# 97   [Sport / by W. Bromley-Davenport ; illustrated...  10.5962  ...
# 98                [Trees-- helping to clean our air??]  10.5962  ...
# 99                    [Price list : January 1, 1925 /]  10.5962  ...
# 100                         [Native and Foreign Trees]  10.5962  ...
#
#     journal-issue.published-print.date-parts institution license abstract  \
# 0                                        NaN         NaN     NaN      NaN
# 1                                        NaN         NaN     NaN      NaN
# 2                                        NaN         NaN     NaN      NaN
# 3                                        NaN         NaN     NaN      NaN
# 4                                        NaN         NaN     NaN      NaN
# ..                                       ...         ...     ...      ...
# 96                                       NaN         NaN     NaN      NaN
# 97                                       NaN         NaN     NaN      NaN
# 98                                       NaN         NaN     NaN      NaN
# 99                                       NaN         NaN     NaN      NaN
# 100                          [[1924, 7, 17]]         NaN     NaN      NaN
#
#      subtype posted.date-parts editor  standards-body.name  \
# 0        NaN               NaN    NaN                  NaN
# 1        NaN               NaN    NaN                  NaN
# 2        NaN               NaN    NaN                  NaN
# 3        NaN               NaN    NaN                  NaN
# 4        NaN               NaN    NaN                  NaN
# ..       ...               ...    ...                  ...
# 96       NaN               NaN    NaN                  NaN
# 97       NaN               NaN    NaN                  NaN
# 98       NaN               NaN    NaN                  NaN
# 99       NaN               NaN    NaN                  NaN
# 100      NaN               NaN    NaN                  NaN
#
#     standards-body.acronym approved.date-parts
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ..                     ...                 ...
# 96                     NaN                 NaN
# 97                     NaN                 NaN
# 98                     NaN                 NaN
# 99                     NaN                 NaN
# 100                    NaN                 NaN
#
# [101 rows x 52 columns]

# %%
# Last bit of cleanup of duplicated first row:
df.drop(index=0, inplace=True)
df
# Out:
#            publisher-location  reference-count  \
# 1                    London :                0
# 2          Washington, D.C. :                0
# 3             Portland, Or. :                0
# 4                         NaN                0
# 5                         NaN                0
# ..                        ...              ...
# 96                    Torino,                0
# 97                   London :                0
# 98         Upper Darby, Pa. :                0
# 99   Marysville, California :                0
# 100                       NaN                0
#
#                                              publisher short-container-title  \
# 1                                           H.G. Bohn,                    []
# 2                           U.S. Dept. of Agriculture,                    []
# 3    Pacific Northwest Forest and Range Experiment ...                    []
# 4                              Smithsonian Institution                    []
# 5                              Smithsonian Institution                    []
# ..                                                 ...                   ...
# 96                                   Giuseppe Cassone,                    []
# 97                                   Chapman and Hall,                    []
# 98             Northeastern Forest Experiment Station,                    []
# 99                               Donald Morse Nursery,                    []
# 100                            Smithsonian Institution                    []
#
#                                  DOI             type    source  \
# 1            10.5962/bhl.title.49941        monograph  Crossref
# 2           10.5962/bhl.title.108915        monograph  Crossref
# 3            10.5962/bhl.title.94153        monograph  Crossref
# 4             10.5962/bhl.part.23369  journal-article  Crossref
# 5    10.5479/si.00963801.30-1462.695  journal-article  Crossref
# ..                               ...              ...       ...
# 96            10.5962/bhl.title.6118        monograph  Crossref
# 97           10.5962/bhl.title.25933        monograph  Crossref
# 98           10.5962/bhl.title.84489        monograph  Crossref
# 99          10.5962/bhl.title.133707        monograph  Crossref
# 100                 10.5962/p.321505  journal-article  Crossref
#
#      is-referenced-by-count  \
# 1                         1
# 2                         1
# 3                         2
# 4                         1
# 5                         2
# ..                      ...
# 96                        0
# 97                        0
# 98                        0
# 99                        0
# 100                       0
#
#                                                  title   prefix  ...  \
# 1    [A selection of the birds of Brazil and Mexico...  10.5962  ...
# 2    [Land reclamation policies in the United State...  10.5962  ...
# 3     [Pruning of ponderosa pine : effect on growth /]  10.5962  ...
# 4          [Zwei neue südamerikanische Microdon-Arten]  10.5962  ...
# 5    [List of fishes collected on Tanega and Yaku, ...  10.5479  ...
# ..                                                 ...      ...  ...
# 96   [Flora medico-farmaceutica, compilata dal dott...  10.5962  ...
# 97   [Sport / by W. Bromley-Davenport ; illustrated...  10.5962  ...
# 98                [Trees-- helping to clean our air??]  10.5962  ...
# 99                    [Price list : January 1, 1925 /]  10.5962  ...
# 100                         [Native and Foreign Trees]  10.5962  ...
#
#     journal-issue.published-print.date-parts institution license abstract  \
# 1                                        NaN         NaN     NaN      NaN
# 2                                        NaN         NaN     NaN      NaN
# 3                                        NaN         NaN     NaN      NaN
# 4                                        NaN         NaN     NaN      NaN
# 5                                   [[1906]]         NaN     NaN      NaN
# ..                                       ...         ...     ...      ...
# 96                                       NaN         NaN     NaN      NaN
# 97                                       NaN         NaN     NaN      NaN
# 98                                       NaN         NaN     NaN      NaN
# 99                                       NaN         NaN     NaN      NaN
# 100                          [[1924, 7, 17]]         NaN     NaN      NaN
#
#      subtype posted.date-parts editor  standards-body.name  \
# 1        NaN               NaN    NaN                  NaN
# 2        NaN               NaN    NaN                  NaN
# 3        NaN               NaN    NaN                  NaN
# 4        NaN               NaN    NaN                  NaN
# 5        NaN               NaN    NaN                  NaN
# ..       ...               ...    ...                  ...
# 96       NaN               NaN    NaN                  NaN
# 97       NaN               NaN    NaN                  NaN
# 98       NaN               NaN    NaN                  NaN
# 99       NaN               NaN    NaN                  NaN
# 100      NaN               NaN    NaN                  NaN
#
#     standards-body.acronym approved.date-parts
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# 5                      NaN                 NaN
# ..                     ...                 ...
# 96                     NaN                 NaN
# 97                     NaN                 NaN
# 98                     NaN                 NaN
# 99                     NaN                 NaN
# 100                    NaN                 NaN
#
# [100 rows x 52 columns]

# %%
df.to_csv('darwin.csv', index=False)
